# %% [markdown]
# Consultas a la API del firewall
# ===========================================

# %% [markdown]
# Requests is good for times when you just need to fetch a webpage and do something with the raw HTML.  It doesn't give you a whole lot more, but does do that incredibly well!  The [Requests homepage](http://docs.python-requests.org/en/latest/) has lots of good examples and full documentation.

# %%
import requests
from requests.auth import HTTPDigestAuth
url = "https://nsa6700.demo.sonicwall.com/api/sonicos/auth"
url2 = "https://nsa6700.demo.sonicwall.com/api/sonicos/address-objects/ipv4"
encabezados = {
   "Accept" : "application/json",
   "Content-type" : "application/json"
}
data = {
   "override" : "true"
}

r = requests.post(url=url, auth=HTTPDigestAuth('demo', 'password'), headers=encabezados, json=data)

# %% [markdown]
# You can make sure the request actually worked (ie. [HTTP status code](http://en.wikipedia.org/wiki/List_of_HTTP_status_codes) 200)

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# You can check what type of content the webpage returned (ie. text, json, csv, etc)

# %%
r2 = requests.get(url2, headers=encabezados)

# %% [markdown]
# You can check the character set (sure hope it is utf-8!)

# %%
r2.status_code
# Out:
# 200

# %% [markdown]
# Of course, you can get the actual HTML text too!

# %%
r2.json()
# Out:
# {'address_objects': [{'ipv4': {'name': 'X0 IP',
#     'uuid': '4ac9cf52-02b5-eecf-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'host': {'ip': '10.150.60.1'}}},
#   {'ipv4': {'name': 'X1 IP',
#     'uuid': '05b110cb-11b8-2ebe-0100-2cb8eda2fcde',
#     'zone': 'WAN',
#     'host': {'ip': '173.240.215.60'}}},
#   {'ipv4': {'name': 'X1 Subnet',
#     'uuid': 'dcf96dda-628c-f16f-0100-2cb8eda2fcde',
#     'zone': 'WAN',
#     'network': {'subnet': '173.240.215.0', 'mask': '255.255.255.0'}}},
#   {'ipv4': {'name': 'X2 IP',
#     'uuid': 'a852500e-050a-efeb-0100-2cb8eda2fcde',
#     'zone': 'WAN',
#     'host': {'ip': '10.254.254.10'}}},
#   {'ipv4': {'name': 'X2 Subnet',
#     'uuid': '9038be3f-bc77-235c-0100-2cb8eda2fcde',
#     'zone': 'WAN',
#     'network': {'subnet': '10.254.254.8', 'mask': '255.255.255.252'}}},
#   {'ipv4': {'name': 'X3 IP',
#     'uuid': '560b637e-14a3-33db-0100-2cb8eda2fcde',
#     'zone': 'Switch',
#     'host': {'ip': '169.254.60.1'}}},
#   {'ipv4': {'name': 'X3 Subnet',
#     'uuid': '1c0be7b8-6973-097e-0100-2cb8eda2fcde',
#     'zone': 'Switch',
#     'network': {'subnet': '169.254.60.0', 'mask': '255.255.255.0'}}},
#   {'ipv4': {'name': 'X4 IP',
#     'uuid': '68fb8e9b-c001-522d-0100-2cb8eda2fcde',
#     'zone': 'WLAN',
#     'host': {'ip': '192.168.60.1'}}},
#   {'ipv4': {'name': 'X4 Subnet',
#     'uuid': '86128b54-51ff-1dc5-0100-2cb8eda2fcde',
#     'zone': 'WLAN',
#     'network': {'subnet': '192.168.60.0', 'mask': '255.255.255.240'}}},
#   {'ipv4': {'name': 'X5 IP',
#     'uuid': '55ec4f11-7da4-eac9-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X5 Subnet',
#     'uuid': '3f00c6a5-8e67-f7bd-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X6 IP',
#     'uuid': 'd9cea963-eb7d-f1c1-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X6 Subnet',
#     'uuid': '2d5fb95b-140b-d386-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X7 IP',
#     'uuid': '57d0823c-2cd7-d658-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X7 Subnet',
#     'uuid': 'b43ac0ae-37c6-cfbf-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X8 IP',
#     'uuid': 'c500441e-cf60-0875-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X8 Subnet',
#     'uuid': 'ec16957a-3026-b485-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X9 IP',
#     'uuid': '1b179fed-66ec-fd62-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X9 Subnet',
#     'uuid': '90db4424-02ef-e74b-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X10 IP',
#     'uuid': '41203130-a687-ba71-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X10 Subnet',
#     'uuid': '2ae09056-e5e4-cc0c-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X11 IP',
#     'uuid': 'a18dd80e-263f-f8e1-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X11 Subnet',
#     'uuid': '51a19d7f-de4b-9575-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X12 IP',
#     'uuid': 'bbd888d0-27cb-30d8-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X12 Subnet',
#     'uuid': 'e6478c5f-ebe2-2273-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X13 IP',
#     'uuid': '71fea28f-e271-367e-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X13 Subnet',
#     'uuid': '2e35f182-ec5a-360e-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X14 IP',
#     'uuid': '919b419b-abc0-c678-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X14 Subnet',
#     'uuid': '97410dff-12b0-4aa4-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X15 IP',
#     'uuid': '755393d2-61a2-4368-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X15 Subnet',
#     'uuid': 'a06fd6d6-2666-19b5-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X16 IP',
#     'uuid': '36210178-50ee-2018-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X16 Subnet',
#     'uuid': 'b400570a-5043-d489-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X17 IP',
#     'uuid': 'ed694cf2-9a34-d771-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X17 Subnet',
#     'uuid': '7fc09b27-e08d-c652-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X18 IP',
#     'uuid': '49608d95-0b35-6773-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X18 Subnet',
#     'uuid': '3c3dd6a5-4726-c51e-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X19 IP',
#     'uuid': '47cc1d0b-e777-8299-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X19 Subnet',
#     'uuid': 'c147b723-bb67-507d-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X20 IP',
#     'uuid': '0a70f4ef-adab-8e5b-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X20 Subnet',
#     'uuid': '8a62aa01-b031-8aae-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X21 IP',
#     'uuid': '7cda80f4-0b33-170d-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X21 Subnet',
#     'uuid': '84317d14-0025-caf7-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X22 IP',
#     'uuid': '21f8f6b7-1a5d-e3ed-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X22 Subnet',
#     'uuid': 'abd49855-2830-d58e-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X23 IP',
#     'uuid': '7c4785e6-fa38-4f7a-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X23 Subnet',
#     'uuid': 'a798c7ba-8c06-6dce-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X24 IP',
#     'uuid': 'f8cf9be9-d1dc-033a-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X24 Subnet',
#     'uuid': '8711a6a3-70c5-e9de-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X25 IP',
#     'uuid': '040a64af-6d65-9072-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X25 Subnet',
#     'uuid': '3027ff9d-65c4-84bb-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X26 IP',
#     'uuid': '1261e9da-fd00-2747-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X26 Subnet',
#     'uuid': '65299d2f-6ff8-6426-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X27 IP',
#     'uuid': 'ac2052f1-ed6f-3e58-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X27 Subnet',
#     'uuid': '3f1afa82-5055-8b35-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X28 IP',
#     'uuid': '62274969-711c-a826-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X28 Subnet',
#     'uuid': '7ebdf7d2-8ddd-c347-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X29 IP',
#     'uuid': 'ca77480f-dfb9-8f73-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X29 Subnet',
#     'uuid': '09dc1ee9-9cf7-b25c-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X30 IP',
#     'uuid': '812205d3-5e0a-c94a-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X30 Subnet',
#     'uuid': '665707c0-2797-af7c-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X31 IP',
#     'uuid': '1eea4df8-a622-536c-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X31 Subnet',
#     'uuid': '39d70d22-f37f-3fd0-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X32 IP',
#     'uuid': '6b9bc778-225b-3634-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X32 Subnet',
#     'uuid': 'c60f07a5-3fc2-9bba-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'X33 IP',
#     'uuid': '611650f8-708a-31f2-0100-2cb8eda2fcde',
#     'host': {}}},
#   {'ipv4': {'name': 'X33 Subnet',
#     'uuid': '3f4156f8-ae28-8d5f-0100-2cb8eda2fcde',
#     'network': {}}},
#   {'ipv4': {'name': 'MGMT IP',
#     'uuid': '3741814f-472d-d00c-0100-2cb8eda2fcde',
#     'zone': 'MGMT',
#     'host': {'ip': '192.168.152.60'}}},
#   {'ipv4': {'name': 'Default Gateway',
#     'uuid': '478524ad-a69a-5949-0100-2cb8eda2fcde',
#     'zone': 'WAN',
#     'host': {}}},
#   {'ipv4': {'name': 'Default Active WAN IP',
#     'uuid': '81392e86-9c03-111c-0100-2cb8eda2fcde',
#     'zone': 'WAN',
#     'host': {'ip': '173.240.215.60'}}},
#   {'ipv4': {'name': 'X0 Subnet',
#     'uuid': 'a5c02150-a47e-748d-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'network': {'subnet': '10.150.60.0', 'mask': '255.255.255.0'}}},
#   {'ipv4': {'name': 'MGMT Default Gateway',
#     'uuid': 'ed3c0c68-58ee-2acd-0100-2cb8eda2fcde',
#     'zone': 'MGMT',
#     'host': {'ip': '192.168.152.1'}}},
#   {'ipv4': {'name': 'X1 Default Gateway',
#     'uuid': 'dcaefea9-4b60-50f2-0100-2cb8eda2fcde',
#     'zone': 'WAN',
#     'host': {'ip': '173.240.215.1'}}},
#   {'ipv4': {'name': 'WAN RemoteAccess Networks',
#     'uuid': 'f826fa28-0cd5-9ac4-0100-2cb8eda2fcde',
#     'zone': 'VPN',
#     'network': {}}},
#   {'ipv4': {'name': 'WLAN RemoteAccess Networks',
#     'uuid': 'e62edd86-7bbb-60c6-0100-2cb8eda2fcde',
#     'zone': 'VPN',
#     'network': {}}},
#   {'ipv4': {'name': 'U0 IP',
#     'uuid': '29b4662c-4f7c-db8b-0100-2cb8eda2fcde',
#     'zone': 'WAN',
#     'host': {}}},
#   {'ipv4': {'name': 'U0 Subnet',
#     'uuid': 'e7eb5280-958a-16e4-0100-2cb8eda2fcde',
#     'zone': 'WAN',
#     'network': {}}},
#   {'ipv4': {'name': 'U0 Default Gateway',
#     'uuid': '6c5ea885-521e-3ed4-0100-2cb8eda2fcde',
#     'zone': 'WAN',
#     'host': {}}},
#   {'ipv4': {'name': 'LiveDemo Main Gateway',
#     'uuid': '00000000-0000-0021-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'host': {'ip': '192.168.150.1'}}},
#   {'ipv4': {'name': 'LiveDemo EMEA DC',
#     'uuid': '00000000-0000-0022-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'host': {'ip': '172.30.13.1'}}},
#   {'ipv4': {'name': 'LiveDemo DC 01',
#     'uuid': '00000000-0000-0023-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'host': {'ip': '192.168.150.8'}}},
#   {'ipv4': {'name': 'LiveDemo DC 02',
#     'uuid': '00000000-0000-0024-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'host': {'ip': '192.168.150.10'}}},
#   {'ipv4': {'name': 'LiveDemo DC 03 (NPS)',
#     'uuid': '00000000-0000-0025-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'host': {'ip': '192.168.150.125'}}},
#   {'ipv4': {'name': 'LiveDemo DNS 01',
#     'uuid': '00000000-0000-0026-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'host': {'ip': '192.168.150.4'}}},
#   {'ipv4': {'name': 'LiveDemo DNS 02',
#     'uuid': '00000000-0000-0027-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'host': {'ip': '192.168.150.5'}}},
#   {'ipv4': {'name': 'LiveDemo Exchange',
#     'uuid': '00000000-0000-0028-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'host': {'ip': '192.168.150.14'}}},
#   {'ipv4': {'name': 'LiveDemo LHM Server',
#     'uuid': '00000000-0000-0029-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'host': {'ip': '192.168.150.115'}}},
#   {'ipv4': {'name': 'LiveDemo Local CFS Responder',
#     'uuid': '00000000-0000-002a-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'host': {'ip': '192.168.150.230'}}},
#   {'ipv4': {'name': 'LiveDemo TimeServer',
#     'uuid': '00000000-0000-002b-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'host': {'ip': '192.168.150.7'}}},
#   {'ipv4': {'name': 'LiveDemo WSUS Server',
#     'uuid': '00000000-0000-002c-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'host': {'ip': '192.168.150.135'}}},
#   {'ipv4': {'name': '192.168.190.0-24',
#     'uuid': '00000000-0000-002d-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'network': {'subnet': '192.168.190.0', 'mask': '255.255.255.0'}}},
#   {'ipv4': {'name': 'X2 Default Gateway',
#     'uuid': '82ecf951-d7b8-322b-0100-2cb8eda2fcde',
#     'zone': 'WAN',
#     'host': {'ip': '10.254.254.9'}}},
#   {'ipv4': {'name': 'X4:V201 IP',
#     'uuid': 'c4e25320-abf9-322a-0100-2cb8eda2fcde',
#     'zone': 'WLANEmployee',
#     'host': {'ip': '192.168.60.129'}}},
#   {'ipv4': {'name': 'X4:V201 Subnet',
#     'uuid': 'ab0a49d5-29eb-0af5-0100-2cb8eda2fcde',
#     'zone': 'WLANEmployee',
#     'network': {'subnet': '192.168.60.128', 'mask': '255.255.255.192'}}},
#   {'ipv4': {'name': 'X4:V202 IP',
#     'uuid': '76f37552-428c-3898-0100-2cb8eda2fcde',
#     'zone': 'WLANGuest',
#     'host': {'ip': '192.168.60.193'}}},
#   {'ipv4': {'name': 'X4:V202 Subnet',
#     'uuid': 'da7c8bc1-5321-417c-0100-2cb8eda2fcde',
#     'zone': 'WLANGuest',
#     'network': {'subnet': '192.168.60.192', 'mask': '255.255.255.192'}}},
#   {'ipv4': {'name': 'X4 SonicPoints',
#     'uuid': 'a4d2ffdd-eaf9-544d-0100-2cb8eda2fcde',
#     'zone': 'WLAN',
#     'range': {'begin': '192.168.60.7', 'end': '192.168.60.14'}}},
#   {'ipv4': {'name': '10.150.102.0',
#     'uuid': '00000000-0000-0037-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'network': {'subnet': '10.150.102.0', 'mask': '255.255.255.0'}}},
#   {'ipv4': {'name': 'SJColo LAN',
#     'uuid': '00000000-0000-0038-0100-2cb8eda2fcde',
#     'zone': 'VPN',
#     'network': {'subnet': '192.168.150.0', 'mask': '255.255.255.0'}}},
#   {'ipv4': {'name': 'HQ LAN',
#     'uuid': '00000000-0000-0039-0100-2cb8eda2fcde',
#     'zone': 'VPN',
#     'network': {'subnet': '10.150.59.0', 'mask': '255.255.255.0'}}},
#   {'ipv4': {'name': 'HQ DC LAN',
#     'uuid': '00000000-0000-003a-0100-2cb8eda2fcde',
#     'zone': 'VPN',
#     'network': {'subnet': '192.168.150.0', 'mask': '255.255.255.0'}}},
#   {'ipv4': {'name': 'NSMVPN-003AA9-138dbd6e',
#     'uuid': '00000000-0000-0041-0100-2cb8eda2fcde',
#     'zone': 'VPN',
#     'network': {'subnet': '192.168.150.0', 'mask': '255.255.255.0'}}},
#   {'ipv4': {'name': 'NSMVPN-003AA9-6f1bf607',
#     'uuid': '00000000-0000-0042-0100-2cb8eda2fcde',
#     'zone': 'VPN',
#     'network': {'subnet': '192.168.150.0', 'mask': '255.255.255.0'}}},
#   {'ipv4': {'name': 'GMSFlow-2CB8EDA2FCDE',
#     'uuid': '00000000-0000-0044-0100-2cb8eda2fcde',
#     'zone': 'LAN',
#     'host': {'ip': '192.168.1.238'}}},
#   {'ipv4': {'name': 'GMSServer-VPN',
#     'uuid': '00000000-0000-0045-0100-2cb8eda2fcde',
#     'zone': 'VPN',
#     'host': {'ip': '173.240.214.251'}}},
#   {'ipv4': {'name': 'toNSsp13700-PrivateWAN Remote Gateway',
#     'uuid': 'c28ced27-30af-21d9-0100-2cb8eda2fcde',
#     'host': {'ip': '10.254.254.2'}}},
#   {'ipv4': {'name': 'toNSsp13700-PublicWAN Remote Gateway',
#     'uuid': '6792b50e-d991-b76d-0100-2cb8eda2fcde',
#     'host': {'ip': '173.240.215.59'}}},
#   {'ipv4': {'name': 'SSO Agent 192.168.150.6',
#     'uuid': 'e89b7d31-2d0e-9e23-0100-2cb8eda2fcde',
#     'zone': 'VPN',
#     'host': {'ip': '192.168.150.6'}}}]}

# %% [markdown]
# But sometimes you just want the header content, for instance if you want to resolve redirects without actually downloading the full webpage content.

# %%
r3 = requests.delete(url, headers=encabezados)

# %%
r3.status_code
# Out:
# 200
